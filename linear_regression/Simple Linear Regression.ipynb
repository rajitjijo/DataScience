# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
import seaborn as sns
import statsmodels.api as sm
sns.set()

# %%
data = pd.read_csv("1.01. Simple linear regression.csv")

# %%
data
# Out:
#      SAT   GPA
# 0   1714  2.40
# 1   1664  2.52
# 2   1760  2.54
# 3   1685  2.74
# 4   1693  2.83
# ..   ...   ...
# 79  1936  3.71
# 80  1810  3.71
# 81  1987  3.73
# 82  1962  3.76
# 83  2050  3.81
#
# [84 rows x 2 columns]

# %%
data.describe()
# Out:
#                SAT        GPA
# count    84.000000  84.000000
# mean   1845.273810   3.330238
# std     104.530661   0.271617
# min    1634.000000   2.400000
# 25%    1772.000000   3.190000
# 50%    1846.000000   3.380000
# 75%    1934.000000   3.502500
# max    2050.000000   3.810000

# %% [markdown]
# We will create a linear regression which predicts the GPA of the student based on the SAT score

# %% [markdown]
# Define the dependent and independent variables

# %%
y = data["GPA"]
x1 = data["SAT"]

# %%
plt.scatter(x1,y)
plt.xlabel("SAT", fontsize=18)
plt.ylabel("GPA", fontsize=18)
plt.show()

# %%
x = sm.add_constant(x1)
results = sm.OLS(y,x).fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    GPA   R-squared:                       0.406
# Model:                            OLS   Adj. R-squared:                  0.399
# Method:                 Least Squares   F-statistic:                     56.05
# Date:                Mon, 13 Oct 2025   Prob (F-statistic):           7.20e-11
# Time:                        22:48:55   Log-Likelihood:                 12.672
# No. Observations:                  84   AIC:                            -21.34
# Df Residuals:                      82   BIC:                            -16.48
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.2750      0.409      0.673      0.503      -0.538       1.088
# ...

# %%
plt.scatter(x1,y)
yhat = 0.00178*x1 + 0.275
fig = plt.plot(x1, yhat, lw=4, c="orange", label="regression line")
plt.xlabel("SAT", fontsize=18)
plt.ylabel("GPA", fontsize=18)
plt.show()

# %%
x
# Out:
#     const   SAT
# 0     1.0  1714
# 1     1.0  1664
# 2     1.0  1760
# 3     1.0  1685
# 4     1.0  1693
# ..    ...   ...
# 79    1.0  1936
# 80    1.0  1810
# 81    1.0  1987
# 82    1.0  1962
# 83    1.0  2050
#
# [84 rows x 2 columns]

# %%
real_estate_data = pd.read_csv("real_estate_price_size.csv")

# %%
real_estate_data
# Out:
#          price     size
# 0   234314.144   643.09
# 1   228581.528   656.22
# 2   281626.336   487.29
# 3   401255.608  1504.75
# 4   458674.256  1275.46
# ..         ...      ...
# 95  252460.400   549.80
# 96  310522.592  1037.44
# 97  383635.568  1504.75
# 98  225145.248   648.29
# 99  274922.856   705.29
#
# [100 rows x 2 columns]

# %%
real_estate_data.describe()
# Out:
#                price         size
# count     100.000000   100.000000
# mean   292289.470160   853.024200
# std     77051.727525   297.941951
# min    154282.128000   479.750000
# 25%    234280.148000   643.330000
# 50%    280590.716000   696.405000
# 75%    335723.696000  1029.322500
# max    500681.128000  1842.510000

# %%
y = real_estate_data["price"]
x1 = real_estate_data["size"]

# %%
plt.scatter(x1,y)
plt.xlabel("size", fontsize=18)
plt.ylabel("price", fontsize=18)
plt.show()

# %%
x_new = sm.add_constant(x1)
results = sm.OLS(y,x_new).fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.745
# Model:                            OLS   Adj. R-squared:                  0.742
# Method:                 Least Squares   F-statistic:                     285.9
# Date:                Mon, 13 Oct 2025   Prob (F-statistic):           8.13e-31
# Time:                        22:59:29   Log-Likelihood:                -1198.3
# No. Observations:                 100   AIC:                             2401.
# Df Residuals:                      98   BIC:                             2406.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1.019e+05   1.19e+04      8.550      0.000    7.83e+04    1.26e+05
# ...

# %% [markdown]
# ### How to interpret the regression table
#
# __coef__ column: __const__ which is the value of the intercept <br>
# __coef__ column: __x__ variable name row is the constant that is multiplied with _x1_
#
# - __std err__ : shows the accuracy of the predicted variables, lower the error better the estimate
# - __t__ and __P>|t|__ : the t statistic and p the p value
#
# #### What does it mean?
# ##### The hypothesis Test is:
# __H0:B=0__ in other words is the coeff = 0, it means if the intercept is 0 the regression line croesses the origin but if the <br>
#
# The __p value__ column tells us how significant that variable is to our model, basically with a p value of less than 0.005 is very good so a 0.000 means that it is highly necessary for the model

# %%
import seaborn as sns
sns.set()

# %%
plt.scatter(x1,y)
yhat = 223.1787*x1 + 1.019e+05
fig = plt.plot(x1, yhat, lw=4, c="orange", label="regression line")
plt.xlabel("SAT", fontsize=18)
plt.ylabel("GPA", fontsize=18)
plt.show()

# %%
945 / 1245
# Out:
# 0.7590361445783133

# %% [markdown]
# # Using SKlearn

# %%
data = pd.read_csv("1.01. Simple linear regression.csv")

# %%
x = data['SAT'] #features
y = data['GPA'] #targets

# %%
x.shape, y.shape
# Out:
# ((84,), (84,))

# %%
x = x.values.reshape(-1,1)
y = y.values.reshape(-1,1)

# %%
x.shape, y.shape
# Out:
# ((84, 1), (84, 1))

# %% [markdown]
# ### Creating the Linear Regression Model

# %%
reg = LinearRegression()

# %%
reg.fit(x,y)
# Out:
# LinearRegression()

# %% [markdown]
# #### RSquared

# %%
reg.score(x,y)
# Out:
# 0.40600391479679765

# %% [markdown]
# ### Coeffecients

# %%
reg.coef_
# Out:
# array([[0.00165569]])

# %% [markdown]
# ### Intercept

# %%
reg.intercept_
# Out:
# array([0.2750403])

# %% [markdown]
# ### Making Predictions

# %%
reg.predict([[1740]])
# Out:
# array([[3.15593751]])

# %%
multi_data = pd.read_csv("1.02. Multiple linear regression.csv")

# %%
multi_data.head()
# Out:
#     SAT  Rand 1,2,3   GPA
# 0  1714           1  2.40
# 1  1664           3  2.52
# 2  1760           3  2.54
# 3  1685           3  2.74
# 4  1693           2  2.83

# %%
y, x = multi_data["GPA"], multi_data[["SAT", "Rand 1,2,3"]]
multi = LinearRegression()
multi.fit(x,y)
# Out:
# LinearRegression()

# %%
multi.coef_
# Out:
# array([ 0.00165354, -0.00826982])

# %%
multi.intercept_
# Out:
# np.float64(0.29603261264909486)

# %% [markdown]
# ### Calculating the R-Squared
#
# #### Formula for adjusted R-Squared
# $R^2_{adj} = 1-(1-R^2)*\frac{n-1}{n-p-1}$
#
# __n__ stands for the number of observations <br>
# __p__ stands for the number of predictors

# %%
r2 = multi.score(x,y)
r2
# Out:
# 0.40668119528142843

# %% [markdown]
# Now using the r squared value we got from the above formula we can calcualte the adjusted r squared value

# %% [markdown]
# ## Feature Selection

# %%
from sklearn.feature_selection import f_regression

# %%
f_regression(x,y)
# Out:
# (array([56.04804786,  0.17558437]), array([7.19951844e-11, 6.76291372e-01]))

# %% [markdown]
# If we look above we geet two outputs in index 0 is the fstatistic for the two features and at index 1 is the pvalue for the featrues, any value greater than 0.05 we ignore that feature

# %%
p_value = f_regression(x,y)[1]

# %%
p_value.round(3)
# Out:
# array([0.   , 0.676])
