# %% [markdown]
# # Simple linear regression - Exercise

# %% [markdown]
# You are given a real estate dataset.
#
# Real estate is one of those examples that every regression course goes through as it is extremely easy to understand and there is a (almost always) certain causal relationship to be found.
#
# The data is located in the file: 'real_estate_price_size.csv'.
#
# You are expected to create a simple linear regression (similar to the one in the lecture), using the new data.
#
# Apart from that, please:
# -  Create a scatter plot (with or without a regression line)
# -  Calculate the R-squared
# -  Display the intercept and coefficient(s)
# -  Using the model make a prediction about an apartment with size 750 sq.ft.
#
# Note: In this exercise, the dependent variable is 'price', while the independent variable is 'size'.
#
# Good luck!

# %% [markdown]
# ## Import the relevant libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
import seaborn as sns
sns.set()

# %% [markdown]
# ## Load the data

# %%
data = pd.read_csv("real_estate_price_size.csv")

# %%
data.head()
# Out:
#         price     size
# 0  234314.144   643.09
# 1  228581.528   656.22
# 2  281626.336   487.29
# 3  401255.608  1504.75
# 4  458674.256  1275.46

# %% [markdown]
# ## Create the regression

# %% [markdown]
# ### Declare the dependent and the independent variables

# %%
y = data["price"].values.reshape(-1,1)
x = data["size"].values.reshape(-1,1)

# %% [markdown]
# ### Explore the data

# %%
plt.scatter(x,y)
plt.xlabel("size")
plt.ylabel("price")
plt.show()

# %% [markdown]
# ### Transform the inputs into a matrix (2D object)

# %%
x.shape, y.shape
# Out:
# ((100, 1), (100, 1))

# %% [markdown]
# ### Regression itself

# %%
model = LinearRegression()
model.fit(x,y)
# Out:
# LinearRegression()

# %% [markdown]
# ### Calculate the R-squared

# %%
model.score(x,y)
# Out:
# 0.7447391865847587

# %% [markdown]
# ### Find the intercept

# %%
model.intercept_
# Out:
# array([101912.60180123])

# %% [markdown]
# ### Find the coefficients

# %%
model.coef_
# Out:
# array([[223.17874259]])

# %% [markdown]
# ### Making predictions
#
# You find an apartment online with a size of 750 sq.ft.
#
# All else equal what should be its price according to the model?

# %%
y_hat = model.predict([[750]])

# %%
print(f"Price of a 750 sq.ft apartment based on our linear model is ${y_hat[0][0]}.")
# Out:
# Price of a 750 sq.ft apartment based on our linear model is $269296.6587471847.
