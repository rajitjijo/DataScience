# %%
import pandas as pd
import numpy as np
import sklearn
from sklearn.linear_model import LogisticRegression
from sklearn import metrics

# %%
data = pd.read_csv("data_preprocessed.csv")

# %%
data.head(10)
# Out:
#          Date  Transportation Expense  Distance to Work  Age  \
# 0  2015-07-07                     289                36   33
# 1  2015-07-14                     118                13   50
# 2  2015-07-15                     179                51   38
# 3  2015-07-16                     279                 5   39
# 4  2015-07-23                     289                36   33
# 5  2015-07-10                     179                51   38
# 6  2015-07-17                     361                52   28
# 7  2015-07-24                     260                50   36
# 8  2015-07-06                     155                12   34
# 9  2015-07-13                     235                11   37
#
#    Daily Work Load Average  Body Mass Index  Education  Children  Pets  \
# 0                  239.554               30          0         2     1
# 1                  239.554               31          0         1     0
# 2                  239.554               31          0         0     0
# 3                  239.554               24          0         2     0
# 4                  239.554               30          0         2     1
# 5                  239.554               31          0         0     0
# 6                  239.554               27          0         1     4
# 7                  239.554               23          0         4     0
# 8                  239.554               25          0         2     0
# 9                  239.554               29          1         1     1
#
#    Absenteeism Time in Hours  Reason_1  Reason_2  Reason_3  Reason_4  \
# 0                          4     False     False     False      True
# 1                          0     False     False     False     False
# 2                          2     False     False     False      True
# 3                          4      True     False     False     False
# 4                          2     False     False     False      True
# 5                          2     False     False     False      True
# 6                          8     False     False     False      True
# 7                          4     False     False     False      True
# 8                         40     False     False      True     False
# 9                          8     False     False     False      True
#
#    Month Values  Day of the Week
# 0             7                1
# 1             7                1
# 2             7                2
# 3             7                3
# 4             7                3
# 5             7                4
# 6             7                4
# 7             7                4
# 8             7                0
# 9             7                0

# %%
data["Absenteeism Time in Hours"].median()
# Out:
# 3.0

# %%
targets = np.where(data['Absenteeism Time in Hours']<data["Absenteeism Time in Hours"].median(),1,0)

# %%
data["Excessive Absenteeism"] = targets

# %%
data.head(10)
# Out:
#          Date  Transportation Expense  Distance to Work  Age  \
# 0  2015-07-07                     289                36   33
# 1  2015-07-14                     118                13   50
# 2  2015-07-15                     179                51   38
# 3  2015-07-16                     279                 5   39
# 4  2015-07-23                     289                36   33
# 5  2015-07-10                     179                51   38
# 6  2015-07-17                     361                52   28
# 7  2015-07-24                     260                50   36
# 8  2015-07-06                     155                12   34
# 9  2015-07-13                     235                11   37
#
#    Daily Work Load Average  Body Mass Index  Education  Children  Pets  \
# 0                  239.554               30          0         2     1
# 1                  239.554               31          0         1     0
# 2                  239.554               31          0         0     0
# 3                  239.554               24          0         2     0
# 4                  239.554               30          0         2     1
# 5                  239.554               31          0         0     0
# 6                  239.554               27          0         1     4
# 7                  239.554               23          0         4     0
# 8                  239.554               25          0         2     0
# 9                  239.554               29          1         1     1
#
#    Absenteeism Time in Hours  Reason_1  Reason_2  Reason_3  Reason_4  \
# 0                          4     False     False     False      True
# 1                          0     False     False     False     False
# 2                          2     False     False     False      True
# 3                          4      True     False     False     False
# 4                          2     False     False     False      True
# 5                          2     False     False     False      True
# 6                          8     False     False     False      True
# 7                          4     False     False     False      True
# 8                         40     False     False      True     False
# 9                          8     False     False     False      True
#
#    Month Values  Day of the Week  Excessive Absenteeism
# 0             7                1                      0
# 1             7                1                      1
# 2             7                2                      1
# 3             7                3                      0
# 4             7                3                      1
# 5             7                4                      1
# 6             7                4                      0
# 7             7                4                      0
# 8             7                0                      0
# 9             7                0                      0

# %%
targets.sum() / targets.shape[0]
# Out:
# np.float64(0.39285714285714285)

# %%
data_with_targets = data.drop(['Absenteeism Time in Hours', 'Date'], axis=1)

# %%
data_with_targets
# Out:
#      Transportation Expense  Distance to Work  Age  Daily Work Load Average  \
# 0                       289                36   33                  239.554
# 1                       118                13   50                  239.554
# 2                       179                51   38                  239.554
# 3                       279                 5   39                  239.554
# 4                       289                36   33                  239.554
# ..                      ...               ...  ...                      ...
# 695                     179                22   40                  237.656
# 696                     225                26   28                  237.656
# 697                     330                16   28                  237.656
# 698                     235                16   32                  237.656
# 699                     291                31   40                  237.656
#
#      Body Mass Index  Education  Children  Pets  Reason_1  Reason_2  Reason_3  \
# 0                 30          0         2     1     False     False     False
# 1                 31          0         1     0     False     False     False
# 2                 31          0         0     0     False     False     False
# 3                 24          0         2     0      True     False     False
# 4                 30          0         2     1     False     False     False
# ..               ...        ...       ...   ...       ...       ...       ...
# 695               22          1         2     0      True     False     False
# 696               24          0         1     2      True     False     False
# 697               25          1         0     0      True     False     False
# 698               25          1         0     0     False     False     False
# 699               25          0         1     1     False     False     False
#
#      Reason_4  Month Values  Day of the Week  Excessive Absenteeism
# 0        True             7                1                      0
# 1       False             7                1                      1
# 2        True             7                2                      1
# 3       False             7                3                      0
# 4        True             7                3                      1
# ..        ...           ...              ...                    ...
# 695     False             5                2                      0
# 696     False             5                2                      0
# 697     False             5                3                      0
# 698      True             5                3                      1
# 699      True             5                3                      1
#
# [700 rows x 15 columns]

# %% [markdown]
# #### Select Inputs

# %%
unscaled_inputs = data_with_targets.iloc[:,:-1]

# %%
scalar = sklearn.preprocessing.StandardScaler()

# %%
scalar.fit(unscaled_inputs)
# Out:
# StandardScaler()

# %% [markdown]
# #### Standardize Inputs

# %%
scaled_inputs = scalar.transform(unscaled_inputs)

# %% [markdown]
# #### Make into dataset

# %%
X_train, X_test, y_train, y_test = sklearn.model_selection.train_test_split(scaled_inputs, targets, test_size=0.2, random_state=42)

# %%
X_train.shape, y_train.shape
# Out:
# ((560, 14), (560,))

# %%
X_test.shape, y_test.shape
# Out:
# ((140, 14), (140,))

# %% [markdown]
# ### Logistic Regression

# %%
model = LogisticRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
model.score(X_train, y_train)
# Out:
# 0.7607142857142857

# %% [markdown]
# #### Manually Checking Score

# %%
model_ouput = model.predict(X_train)

# %%
np.sum((model_ouput == y_train)) / model_ouput.shape[0]
# Out:
# np.float64(0.7607142857142857)

# %% [markdown]
# ### Intercepts and Coeffecients

# %%
model.intercept_
# Out:
# array([-0.6648332])

# %%
model.coef_
# Out:
# array([[-0.44506876, -0.12423716,  0.31276019,  0.16783073, -0.31339497,
#          0.1502103 , -0.46785063,  0.30348605, -2.34119336, -0.3077652 ,
#         -1.58259014, -1.57348768, -0.01512182, -0.02571605]])

# %%
unscaled_inputs.columns.values
# Out:
# array(['Transportation Expense', 'Distance to Work', 'Age',
#        'Daily Work Load Average', 'Body Mass Index', 'Education',
#        'Children', 'Pets', 'Reason_1', 'Reason_2', 'Reason_3', 'Reason_4',
#        'Month Values', 'Day of the Week'], dtype=object)

# %%
summary_table = pd.DataFrame(columns=["Features"], data = unscaled_inputs.columns.values)
summary_table["Coefficients"] = np.transpose(model.coef_)

# %%
summary_table
# Out:
#                    Features  Coefficients
# 0    Transportation Expense     -0.445069
# 1          Distance to Work     -0.124237
# 2                       Age      0.312760
# 3   Daily Work Load Average      0.167831
# 4           Body Mass Index     -0.313395
# 5                 Education      0.150210
# 6                  Children     -0.467851
# 7                      Pets      0.303486
# 8                  Reason_1     -2.341193
# 9                  Reason_2     -0.307765
# 10                 Reason_3     -1.582590
# 11                 Reason_4     -1.573488
# 12             Month Values     -0.015122
# 13          Day of the Week     -0.025716

# %%
summary_table.index = summary_table.index + 1
summary_table.loc[0] = ["Intercept", model.intercept_[0]]
summary_table = summary_table.sort_index()

# %%
summary_table
# Out:
#                    Features  Coefficients
# 0                 Intercept     -0.664833
# 1    Transportation Expense     -0.445069
# 2          Distance to Work     -0.124237
# 3                       Age      0.312760
# 4   Daily Work Load Average      0.167831
# 5           Body Mass Index     -0.313395
# 6                 Education      0.150210
# 7                  Children     -0.467851
# 8                      Pets      0.303486
# 9                  Reason_1     -2.341193
# 10                 Reason_2     -0.307765
# 11                 Reason_3     -1.582590
# 12                 Reason_4     -1.573488
# 13             Month Values     -0.015122
# 14          Day of the Week     -0.025716

# %%
summary_table["Odds_ratio"] = np.exp(summary_table.Coefficients)

# %%
summary_table
# Out:
#                    Features  Coefficients  Odds_ratio
# 0                 Intercept     -0.664833    0.514359
# 1    Transportation Expense     -0.445069    0.640780
# 2          Distance to Work     -0.124237    0.883170
# 3                       Age      0.312760    1.367194
# 4   Daily Work Load Average      0.167831    1.182736
# 5           Body Mass Index     -0.313395    0.730961
# 6                 Education      0.150210    1.162079
# 7                  Children     -0.467851    0.626347
# 8                      Pets      0.303486    1.354573
# 9                  Reason_1     -2.341193    0.096213
# 10                 Reason_2     -0.307765    0.735088
# 11                 Reason_3     -1.582590    0.205442
# 12                 Reason_4     -1.573488    0.207321
# 13             Month Values     -0.015122    0.984992
# 14          Day of the Week     -0.025716    0.974612

# %%
summary_table.sort_values('Odds_ratio', ascending=False)
# Out:
#                    Features  Coefficients  Odds_ratio
# 3                       Age      0.312760    1.367194
# 8                      Pets      0.303486    1.354573
# 4   Daily Work Load Average      0.167831    1.182736
# 6                 Education      0.150210    1.162079
# 13             Month Values     -0.015122    0.984992
# 14          Day of the Week     -0.025716    0.974612
# 2          Distance to Work     -0.124237    0.883170
# 10                 Reason_2     -0.307765    0.735088
# 5           Body Mass Index     -0.313395    0.730961
# 1    Transportation Expense     -0.445069    0.640780
# 7                  Children     -0.467851    0.626347
# 0                 Intercept     -0.664833    0.514359
# 12                 Reason_4     -1.573488    0.207321
# 11                 Reason_3     -1.582590    0.205442
# 9                  Reason_1     -2.341193    0.096213
